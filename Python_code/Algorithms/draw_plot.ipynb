# %% [markdown]
# # Pha test của các thuật toán

# %%
NUMS_TASK = 4000
iters = 9
eps = 120
loops = 1
REWARD_DROP=[-1]
algorithms=['local','shortest distance','shortest queue','Round_Robin','rl']
colors = ['blue', 'red', 'green', 'black','orange','yellow']

# %%
  
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
from pathlib import Path

LINK_PROJECT = Path(os.path.abspath('draw_plot.ipynb')).parent.parent
print(LINK_PROJECT)
result=dict()
result_info=dict()
j=0
for algorithm in algorithms:
    with open(f"{LINK_PROJECT}/result/test/{algorithm}/sum_tolerance_time.csv", "r") as file:
        result[algorithm] = pd.read_csv(file)
    columns = ['sum_tolerance_time'][0]

    minrange = 0
    maxrange = -1

    result_info[algorithm] = result[algorithm][columns][minrange:maxrange]
    plt.plot(result_info[algorithm],color=colors[j], label = f"{algorithm}")
    plt.axhline(np.mean(result_info[algorithm]),color=colors[j], linestyle='--', label=f'Giá trị trung bình {algorithm} ')
    print(f"Mean :", np.mean(result_info[algorithm]))
    j+=1


        # plt.ylim(-0.05, -0)
plt.title( f'Biểu đồ TOLERANCE_TIME với giá trị trung bình  ')
plt.legend(loc='upper right',bbox_to_anchor=(1.7, 1), ncol=1, fancybox=True)
# plt.savefig(f"{LINK_PROJECT}/fig/{which_algorithm}/env_2_4/5vehicle/{NUMS_TASK}task/num_iters{iters}/eps{eps}/Biểu đồ TOLERANCE_TIME với giá trị trung bình trong pha Test-{which_algorithm}-reward_drop:{reward_drop}.png")
plt.show()
# Out:
# d:\Lab\Lab_project\Dead_or_alive
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 13
#      11 j=0
#      12 for algorithm in algorithms:
# ---> 13     with open(f"{LINK_PROJECT}/result/test/{algorithm}/sum_tolerance_time.csv", "r") as file:
#      14         result[algorithm] = pd.read_csv(file)
#      15     columns = ['sum_tolerance_time'][0]
#
# File d:\App\Anaconda\envs\Bus_env\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'd:\\Lab\\Lab_project\\Dead_or_alive/result/test/local/sum_tolerance_time.csv'

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
from pathlib import Path

LINK_PROJECT = Path(os.path.abspath('draw_plot.ipynb')).parent.parent
print(LINK_PROJECT)
result=dict()
result_info=dict()
j=0
for algorithm in algorithms:
    with open(f"{LINK_PROJECT}/result/test/{algorithm}/reward.csv", "r") as file:
        result[algorithm] = pd.read_csv(file)
    columns = ['reward'][0]

    minrange = 0
    maxrange = -1

    result_info[algorithm] = result[algorithm][columns][minrange:maxrange]
    plt.plot(result_info[algorithm],color=colors[j], label = f"{algorithm}")
    plt.axhline(np.mean(result_info[algorithm]),color=colors[j], linestyle='--', label=f'Giá trị trung bình {algorithm} ')
    print(f"Mean :", np.mean(result_info[algorithm]))
    j+=1


        # plt.ylim(-0.05, -0)
plt.title( f'Biểu đồ reward với giá trị trung bình ')
plt.legend(bbox_to_anchor=(1.7, 1), ncol=1, fancybox=True)
# plt.savefig(f"{LINK_PROJECT}/fig/{which_algorithm}/env_2_4/5vehicle/{NUMS_TASK}task/num_iters{iters}/eps{eps}/Biểu đồ TOLERANCE_TIME với giá trị trung bình trong pha Test-{which_algorithm}-reward_drop:{reward_drop}.png")
plt.show()
# Out:
# d:\Lab\Lab_project\Dead_or_alive
# Mean : -20.78228729147036
# Mean : -0.543120776343065
# Mean : -34.66712240021438
# Mean : -102.17029163699003
# Mean : -64.07068269614435
